# %%
# %%capture
from covid import ontario, plots
model, result = ontario.train()

# %% [markdown]
# ## COVID-19 Effective Reproduction Rate (Rt)
# [BC](https://rtlive.ca/bc.html) - **Ontario** - [Alberta](https://rtlive.ca/alberta.html) - [Quebec](https://rtlive.ca/quebec.html)

# %%
plots.rt(model, result)
# Out:
# <div>
#
#
#             <div id="b2b48274-e458-4944-90b0-e5342c87ec81" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b2b48274-e458-4944-90b0-e5342c87ec81")) {
#                     Plotly.newPlot(
#                         'b2b48274-e458-4944-90b0-e5342c87ec81',
# ...

# %% [markdown]
# ## Positive Tests

# %%
plots.positives(result)
# Out:
# <div>
#
#
#             <div id="840b189f-1176-47e5-bda4-5a5201d3935f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("840b189f-1176-47e5-bda4-5a5201d3935f")) {
#                     Plotly.newPlot(
#                         '840b189f-1176-47e5-bda4-5a5201d3935f',
# ...

# %% [markdown]
# ## Testing Volume

# %%
plots.tests(result)
# Out:
# <div>
#
#
#             <div id="ad1d6d97-7d5d-4226-9e27-ee0a4ed566e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ad1d6d97-7d5d-4226-9e27-ee0a4ed566e0")) {
#                     Plotly.newPlot(
#                         'ad1d6d97-7d5d-4226-9e27-ee0a4ed566e0',
# ...
