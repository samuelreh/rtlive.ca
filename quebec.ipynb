# %%
# %%capture
from covid import quebec, plots
model, result = quebec.train()

# %% [markdown]
# ## COVID-19 Effective Reproduction Rate (Rt)
# [BC](https://rtlive.ca/bc.html) - [Ontario](https://rtlive.ca/ontario.html) - [Alberta](https://rtlive.ca/alberta.html) - **Quebec**

# %%
plots.rt(model, result)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b95b80046117> in <module>
# ----> 1 plots.rt(model, result)
#
# NameError: name 'plots' is not defined

# %% [markdown]
# ## Positive Tests

# %%
plots.positives(result)
# Out:
# <div>
#
#
#             <div id="840b189f-1176-47e5-bda4-5a5201d3935f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("840b189f-1176-47e5-bda4-5a5201d3935f")) {
#                     Plotly.newPlot(
#                         '840b189f-1176-47e5-bda4-5a5201d3935f',
# ...

# %% [markdown]
# ## Testing Volume

# %%
plots.tests(result)
# Out:
# <div>
#
#
#             <div id="ad1d6d97-7d5d-4226-9e27-ee0a4ed566e0" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("ad1d6d97-7d5d-4226-9e27-ee0a4ed566e0")) {
#                     Plotly.newPlot(
#                         'ad1d6d97-7d5d-4226-9e27-ee0a4ed566e0',
# ...
